# %%
import numpy as np
from tools.parser import qiecodes,parse_text_file,convert_int
import matplotlib.pyplot as plt

# %%
ch4,ampl4, tdc4, bx4 = parse_text_file("../uHTR_data/2022_07_06/uHTR_4.txt",stop_event=-1)
# Out:
# /Users/rsaradhy/work/bril/bhm_tools/tools/parser.py:90: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray(CH),np.asarray(AMPL),np.asarray(TDC),np.asarray(BX)

# %%
X = np.arange(0,len(ampl4[0])*25,25)
plt.plot(X,qiecodes[ampl4[0]],color='k')
plt.scatter(X,qiecodes[ampl4[0]],marker=".",color='r')
plt.xlabel("Time [ns]")
plt.ylabel("Linearized Ampl [ADC]")
# Out:
# Text(0, 0.5, 'Linearized Ampl [ADC]')

# %%
counts, bins, _=plt.hist(bx4,bins=np.arange(-.5,3564,1),label="uHTR_4")
_=plt.xlabel("Bunch Crossing ID")
_=plt.ylabel("Hits")
_=plt.yscale("log")
_=plt.legend(loc='upper right',frameon=True)
